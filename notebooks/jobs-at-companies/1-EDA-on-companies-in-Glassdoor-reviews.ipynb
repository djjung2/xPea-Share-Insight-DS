# %% [markdown]
# # Exploratory data analysis on companies in Glassdoor reviews
#
# In this notebook, I will begin doing some EDA on the Glassdoor Reviews dataset. This dataset contains over 2.5 million reviews on over 5,500 publicly traded companies. I will then create a `companies` DataFrame that contains info on every company reviewed in the dataset. Finally, I will create a `reviews_company_status_title_counts` DataFrame that states how many each times each company-title pair has been reviewed at each company. I will save these last two DataFrames to CSV's for future use.
#
# I will remove reviews that have strange formatting, like improperly written job title. The number of reviews I remove will total up to less than $1\%$, so I won't worry about it too much.
#
# <b> As a part of using this data from Thinknum, I will not be able to show the data, but I can show my results and analysis.</b>

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)

import time

# %%
#import Glassdoor reviews
reviews = pd.read_csv('glassdoor_reviews_2.csv')

# %%
print('Number of unique company IDs: {}'.format(reviews.loc[:,'Company Id'].nunique()))
# Out:
# Number of unique company IDs: 5833

# %%
print('Number of reviews: {}'.format(reviews.shape[0]))
print('Number of columns: {}'.format(reviews.shape[1]))

print('-'*50)

print('Columns:')

reviews.columns
# Out:
# Number of reviews: 2631927
# Number of columns: 35
# --------------------------------------------------
# Columns:
# Index(['Ticker Symbol', 'Entity Name', 'Dataset', 'CUSIP', 'ISIN', 'Unique ID',
#        'As Of Date', 'Review Url', 'Logo', 'Author Title', 'Author Location',
#        'Author Country', 'Summary', 'Description', 'PROs', 'CONs',
#        'Recommends Value', 'Recommends Description', 'Outlook Value',
#        'Outlook Description', 'CEO Review Value', 'CEO Review Description',
#        'Helpful Count', 'Rating: Overall', 'Rating: Work/Life Balance',
#        'Rating: Culture & Values', 'Rating: Career Opportunities',
#        'Rating: Comp & Benefits', 'Rating: Senior Management', 'Company Id',
#        'Company URL', 'Date Added', 'Date Updated', 'Ticker Sector',
#        'Ticker Industry'],
#       dtype='object')

# %%
reviews.dtypes
# Out:
# Ticker Symbol                    object
# Entity Name                      object
# Dataset                           int64
# CUSIP                            object
# ISIN                             object
# Unique ID                         int64
# As Of Date                       object
# Review Url                       object
# Logo                             object
# Author Title                     object
# Author Location                  object
# Author Country                   object
# Summary                          object
# Description                      object
# PROs                             object
# CONs                             object
# Recommends Value                float64
# Recommends Description           object
# Outlook Value                   float64
# Outlook Description              object
# CEO Review Value                float64
# CEO Review Description           object
# Helpful Count                   float64
# Rating: Overall                   int64
# Rating: Work/Life Balance       float64
# Rating: Culture & Values        float64
# Rating: Career Opportunities    float64
# Rating: Comp & Benefits         float64
# Rating: Senior Management       float64
# Company Id                        int64
# Company URL                      object
# Date Added                       object
# Date Updated                     object
# Ticker Sector                    object
# Ticker Industry                  object
# dtype: object

# %% [markdown]
# ## Companies DataFrame
#
# In this section, I will create a DataFrame containing info on every company reviewed. The columns will be:
# - `Ticker Symbol`
# - `Ticker Sector`
# - `Ticker Industry`
# - `Company Id`
# - `Company URL`
# - `company_name`
# - `count`: number of times company has been reviewed at company.
#
# I think the rest of the columns are self-explanatory.
#
# We will use this DataFrame later when we filter our analysis to companies with a minimum number of reviews. Also, we will use the Company ID to distinguish companies later when analyzing employee sentiment.

# %% [markdown]
# ### Extract company names from URL's for 100 reviews

# %%
#extract first 101 reviews
reviews_first_hundred = reviews.loc[:100,:].copy()

reviews_first_hundred.shape
# Out:
# (101, 35)

# %% [markdown]
# One column of the reviews DataFrame is the company URL of the reviewed company. An example URL is https://www.glassdoor.com/Overview/Working-at-Genentech-EI_IE274.11,20.htm, where the reviewed company is Genentech. To extract 'Genentech', we will naively just split by '-' and select the second item.

# %%
#extract company name from company URL by split
reviews_first_hundred.loc[:,'company_name'] = reviews_first_hundred.loc[:,'Company URL'].apply(lambda x: x.split('-')[2])

# %%
for idx in range(101):
    print('Index: {}'.format(idx))
    print('URL: {}'.format(reviews_first_hundred.loc[idx,'Company URL']))
    print('Name: {}'.format(reviews_first_hundred.loc[idx,'company_name']))
    print('-'*50)
# Out:
# Index: 0
# URL: https://www.glassdoor.com/Overview/Working-at-Genentech-EI_IE274.11,20.htm
# Name: Genentech
# --------------------------------------------------
# Index: 1
# URL: https://www.glassdoor.com/Overview/Working-at-Falabella-EI_IE10976.11,20.htm
# Name: Falabella
# --------------------------------------------------
# Index: 2
# URL: https://www.glassdoor.com/Overview/Working-at-Big-W-EI_IE473193.11,16.htm
# Name: Big
# --------------------------------------------------
# Index: 3
# URL: https://www.glassdoor.com/Overview/Working-at-WorleyParsons-EI_IE35193.11,24.htm
# Name: WorleyParsons
# --------------------------------------------------
# Index: 4
# URL: https://www.glassdoor.com/Overview/Working-at-ExxonMobil-EI_IE237.11,21.htm
# Name: ExxonMobil
# --------------------------------------------------
# Index: 5
# URL: https://www.glassdoor.com/Overview/Working-at-Caterpillar-EI_IE137.11,22.htm
# Name: Caterpillar
# --------------------------------------------------
# Index: 6
# URL: https://www.glassdoor.com/Overview/Working-at-WestRock-EI_IE1033056.11,19.htm
# Name: WestRock
# --------------------------------------------------
# Index: 7
# URL: https://www.glassdoor.com/Overview/Working-at-Corrections-Corporation-of-America-EI_IE6826.11,45.htm
# Name: Corrections
# --------------------------------------------------
# Index: 8
# URL: https://www.glassdoor.com/Overview/Working-at-Micro-Focus-EI_IE15057.11,22.htm
# Name: Micro
# --------------------------------------------------
# Index: 9
# URL: https://www.glassdoor.com/Overview/Working-at-PHH-Mortgage-EI_IE17798.11,23.htm
# Name: PHH
# --------------------------------------------------
# Index: 10
# URL: https://www.glassdoor.com/Overview/Working-at-Securitas-Security-Services-USA-EI_IE16559.11,42.htm
# Name: Securitas
# --------------------------------------------------
# Index: 11
# URL: https://www.glassdoor.com/Overview/Working-at-Goldman-Sachs-EI_IE2800.11,24.htm
# Name: Goldman
# --------------------------------------------------
# Index: 12
# URL: https://www.glassdoor.com/Overview/Working-at-Oracle-EI_IE1737.11,17.htm
# Name: Oracle
# --------------------------------------------------
# Index: 13
# URL: https://www.glassdoor.com/Overview/Working-at-Sherwin-Williams-EI_IE599.11,27.htm
# Name: Sherwin
# --------------------------------------------------
# Index: 14
# URL: https://www.glassdoor.com/Overview/Working-at-Synovus-EI_IE1202.11,18.htm
# Name: Synovus
# --------------------------------------------------
# Index: 15
# URL: https://www.glassdoor.com/Overview/Working-at-Lockheed-Martin-EI_IE404.11,26.htm
# Name: Apple
# --------------------------------------------------
# Index: 99
# URL: https://www.glassdoor.com/Overview/Working-at-Majestic-Wine-EI_IE25592.11,24.htm
# Name: Majestic
# --------------------------------------------------
# Index: 100
# URL: https://www.glassdoor.com/Overview/Working-at-Burlington-Stores-EI_IE114.11,28.htm
# Name: Burlington
# --------------------------------------------------

# %% [markdown]
# We see that we run into an issue for companies with names that are more than 1 word. Thus, on the split by '-', we will select the list items from the second index to the second to last.

# %%
reviews_first_hundred.loc[:,'company_name'] = reviews_first_hundred.loc[:,'Company URL'].apply(lambda x: " ".join(x.split('-')[2:-1]))

# %%
#check that extraction of company name worked for first 100 reviews
for idx in range(101):
    print('Index: {}'.format(idx))
    print('URL: {}'.format(reviews_first_hundred.loc[idx,'Company URL']))
    print('Name: {}'.format(reviews_first_hundred.loc[idx,'company_name']))
    print('-'*50)
# Out:
# Index: 0
# URL: https://www.glassdoor.com/Overview/Working-at-Genentech-EI_IE274.11,20.htm
# Name: Genentech
# --------------------------------------------------
# Index: 1
# URL: https://www.glassdoor.com/Overview/Working-at-Falabella-EI_IE10976.11,20.htm
# Name: Falabella
# --------------------------------------------------
# Index: 2
# URL: https://www.glassdoor.com/Overview/Working-at-Big-W-EI_IE473193.11,16.htm
# Name: Big W
# --------------------------------------------------
# Index: 3
# URL: https://www.glassdoor.com/Overview/Working-at-WorleyParsons-EI_IE35193.11,24.htm
# Name: WorleyParsons
# --------------------------------------------------
# Index: 4
# URL: https://www.glassdoor.com/Overview/Working-at-ExxonMobil-EI_IE237.11,21.htm
# Name: ExxonMobil
# --------------------------------------------------
# Index: 5
# URL: https://www.glassdoor.com/Overview/Working-at-Caterpillar-EI_IE137.11,22.htm
# Name: Caterpillar
# --------------------------------------------------
# Index: 6
# URL: https://www.glassdoor.com/Overview/Working-at-WestRock-EI_IE1033056.11,19.htm
# Name: WestRock
# --------------------------------------------------
# Index: 7
# URL: https://www.glassdoor.com/Overview/Working-at-Corrections-Corporation-of-America-EI_IE6826.11,45.htm
# Name: Corrections Corporation of America
# --------------------------------------------------
# Index: 8
# URL: https://www.glassdoor.com/Overview/Working-at-Micro-Focus-EI_IE15057.11,22.htm
# Name: Micro Focus
# --------------------------------------------------
# Index: 9
# URL: https://www.glassdoor.com/Overview/Working-at-PHH-Mortgage-EI_IE17798.11,23.htm
# Name: PHH Mortgage
# --------------------------------------------------
# Index: 10
# URL: https://www.glassdoor.com/Overview/Working-at-Securitas-Security-Services-USA-EI_IE16559.11,42.htm
# Name: Securitas Security Services USA
# --------------------------------------------------
# Index: 11
# URL: https://www.glassdoor.com/Overview/Working-at-Goldman-Sachs-EI_IE2800.11,24.htm
# Name: Goldman Sachs
# --------------------------------------------------
# Index: 12
# URL: https://www.glassdoor.com/Overview/Working-at-Oracle-EI_IE1737.11,17.htm
# Name: Oracle
# --------------------------------------------------
# Index: 13
# URL: https://www.glassdoor.com/Overview/Working-at-Sherwin-Williams-EI_IE599.11,27.htm
# Name: Sherwin Williams
# --------------------------------------------------
# Index: 14
# URL: https://www.glassdoor.com/Overview/Working-at-Solvay-EI_IE5509.11,17.htm
# Name: Solvay
# --------------------------------------------------
# Index: 96
# URL: https://www.glassdoor.com/Overview/Working-at-Starbucks-EI_IE2202.11,20.htm
# Name: Starbucks
# --------------------------------------------------
# Index: 97
# URL: https://www.glassdoor.com/Overview/Working-at-Surgery-Partners-EI_IE386053.11,27.htm
# Name: Surgery Partners
# --------------------------------------------------
# Index: 98
# URL: https://www.glassdoor.com/Overview/Working-at-Apple-EI_IE1138.11,16.htm
# Name: Apple
# --------------------------------------------------
# Index: 99
# URL: https://www.glassdoor.com/Overview/Working-at-Majestic-Wine-EI_IE25592.11,24.htm
# Name: Majestic Wine
# --------------------------------------------------
# Index: 100
# URL: https://www.glassdoor.com/Overview/Working-at-Burlington-Stores-EI_IE114.11,28.htm
# Name: Burlington Stores
# --------------------------------------------------

# %% [markdown]
# ### Create companies DataFrame for all reviews

# %%
#finds number of distinct companies
reviews.loc[:,'Company URL'].nunique()
# Out:
# 5851

# %%
#Creates companies DataFrame
companies = reviews.loc[:,['Ticker Symbol',
                           'Ticker Sector', 
                           'Ticker Industry',
                           'Company Id', 
                           'Company URL']].drop_duplicates()

# %%
#finds Company ID's are repeated in companies dataframe
companies.loc[:,'Company Id'].value_counts()
# Out:
# 3480       3
# 14916      3
# 367190     3
# 3477       3
# 42406      2
# 975783     2
# 14790      2
# 1985       2
# 9347       2
# 10350      2
# 10648      2
# 658        2
# 8347       2
# 8690       2
# 3489       2
# 7330       2
# 1337673    2
# 40260      2
# 13598      2
# 930001     2
# 320880     2
# 11978      2
# 1190       2
# 3322       2
# 234929     2
# 241146     2
# 42820      2
# 733735     1
# 236210     1
# 2732       1
#           ..
# 8843       1
# 9622       1
# 11671      1
# 3925       1
# 14984      1
# 252482     1
# 2151       1
# 17798      1
# 261509     1
# 300420     1
# 992630     1
# 295        1
# 7525       1
# 1382       1
# 21864      1
# 9578       1
# 1390       1
# 972144     1
# 4736       1
# 19831      1
# 3459       1
# 17786      1
# 11046      1
# 5500       1
# 7549       1
# 943486     1
# 22669      1
# 42511      1
# 1410       1
# 18433      1
# Name: Company Id, dtype: int64

# %%
#find that there can be multiple compay URL's for same company ID
companies_roche = companies[companies['Company Id']==3480]

for idx in [209,517,49989]:
    print(companies_roche.loc[idx,'Company URL'])
# Out:
# https://www.glassdoor.com/Overview/Working-at-Roche-EI_IE3480.11,16.htm
# https://www.glassdoor.com/Overview/Working-at-Roche-Sequencing-Solutions-EI_IE42543.11,37.htm
# https://www.glassdoor.com/Overview/Working-at-454-Life-Sciences-EI_IE13757.11,28.htm

# %%
companies[companies['Company Id']==14916]
# Out:
#         Ticker Symbol Ticker Sector   Ticker Industry  Company Id  \
# 1387      nasdaq:rjet           NaN  Travel & Leisure       14916
# 46859     nasdaq:rjet           NaN  Travel & Leisure       14916
# 2173207   nasdaq:rjet           NaN  Travel & Leisure       14916
#
#                                                Company URL
# 1387     https://www.glassdoor.com/Overview/Working-at-...
# 46859    https://www.glassdoor.com/Overview/Working-at-...
# 2173207  https://www.glassdoor.com/Overview/Working-at-...

# %%
#23 companies have two url's
#4 companies have three url's
companies.loc[:,'Company Id'].value_counts().value_counts()
# Out:
# 1    5806
# 2      23
# 3       4
# Name: Company Id, dtype: int64

# %%
#company ID's with three URL's
three_urls = companies.loc[:,'Company Id'].value_counts().index.tolist()[:4]

#company ID's with two URL's
two_urls = companies.loc[:,'Company Id'].value_counts().index.tolist()[4:4+23]

# %%
three_urls
# Out:
# [3480, 14916, 367190, 3477]

# %%
#find three URL's corresponding to Caesar's Entertainment (legacy names)
companies[companies['Company Id'] == three_urls[2]].loc[:,'Company URL'].apply(lambda x: print(x))
# Out:
# https://www.glassdoor.com/Overview/Working-at-Caesars-Entertainment-EI_IE367190.11,32.htm
# https://www.glassdoor.com/Overview/Working-at-World-Series-of-Poker-WSOP-EI_IE473728.11,37.htm
# https://www.glassdoor.com/Overview/Working-at-Rio-All-Suite-Hotel-and-Casino-EI_IE1614.11,41.htm
# 593        None
# 45386      None
# 1249987    None
# Name: Company URL, dtype: object

# %%
#print URL's for company ID's with multiple URL's

print('Three urls')

print('-'*50)

for company_id in three_urls:
    print('Company ID: {}'.format(company_id))
    companies[companies['Company Id']==company_id].loc[:,'Company URL'].apply(lambda x: print(x))
    print('-'*50)
    
print('-'*50)
print('-'*50)
print('-'*50)
    

print('Two urls')

print('-'*50)
print('-'*50)
print('-'*50)
    
for company_id in two_urls:
    print('Company ID: {}'.format(company_id))
    companies[companies['Company Id']==company_id].loc[:,'Company URL'].apply(lambda x: print(x))
    print('-'*50)
    
#PRA Group is second: 975783
#Union Bank is second: 1985
#Sanofi is second: 9347
#OSRAM is second: 10648
#OneMain Financial is second: 13598
#Uniqlo is second: 320880
#Bob Evans Restaurant is second: 1190
# Out:
# Three urls
# --------------------------------------------------
# Company ID: 3480
# https://www.glassdoor.com/Overview/Working-at-Roche-EI_IE3480.11,16.htm
# https://www.glassdoor.com/Overview/Working-at-Roche-Sequencing-Solutions-EI_IE42543.11,37.htm
# https://www.glassdoor.com/Overview/Working-at-454-Life-Sciences-EI_IE13757.11,28.htm
# --------------------------------------------------
# Company ID: 14916
# https://www.glassdoor.com/Overview/Working-at-Republic-Airways-EI_IE14916.11,27.htm
# https://www.glassdoor.com/Overview/Working-at-Chautauqua-Airlines-EI_IE14353.11,30.htm
# https://www.glassdoor.com/Overview/Working-at-Shuttle-America-EI_IE22257.11,26.htm
# --------------------------------------------------
# Company ID: 367190
# https://www.glassdoor.com/Overview/Working-at-Caesars-Entertainment-EI_IE367190.11,32.htm
# https://www.glassdoor.com/Overview/Working-at-World-Series-of-Poker-WSOP-EI_IE473728.11,37.htm
# https://www.glassdoor.com/Overview/Working-at-Rio-All-Suite-Hotel-and-Casino-EI_IE1614.11,41.htm
# --------------------------------------------------
# Company ID: 3477
# https://www.glassdoor.com/Overview/Working-at-GlaxoSmithKline-EI_IE3477.11,26.htm
# https://www.glassdoor.com/Overview/Working-at-GlaxoSmithKline-Consumer-Healthcare-EI_IE39188.11,46.htm
# https://www.glassdoor.com/Overview/Working-at-GlaxoSmithKline-Pharmaceuticals-EI_IE38907.11,42.htm
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# Company ID: 40260
# https://www.glassdoor.com/Overview/Working-at-Viacom-EI_IE40260.11,17.htm
# https://www.glassdoor.com/Overview/Working-at-Viacom-Media-Networks-EI_IE12103.11,32.htm
# --------------------------------------------------
# Company ID: 13598
# https://www.glassdoor.com/Overview/Working-at-Springleaf-Finance-EI_IE411618.11,29.htm
# https://www.glassdoor.com/Overview/Working-at-OneMain-Financial-EI_IE13598.11,28.htm
# --------------------------------------------------
# Company ID: 930001
# https://www.glassdoor.com/Overview/Working-at-Outfront-Media-EI_IE930001.11,25.htm
# https://www.glassdoor.com/Overview/Working-at-CBS-Outdoor-EI_IE19648.11,22.htm
# --------------------------------------------------
# Company ID: 320880
# https://www.glassdoor.com/Overview/Working-at-Uniqlo-Usa-EI_IE312278.11,21.htm
# https://www.glassdoor.com/Overview/Working-at-Uniqlo-EI_IE320880.11,17.htm
# --------------------------------------------------
# Company ID: 11978
# https://www.glassdoor.com/Overview/Working-at-Kaplan-EI_IE11978.11,17.htm
# https://www.glassdoor.com/Overview/Working-at-Kaplan-K12-Learning-Services-EI_IE307923.11,39.htm
# --------------------------------------------------
# Company ID: 1190
# https://www.glassdoor.com/Overview/Working-at-Bob-Evans-EI_IE1190.11,20.htm
# https://www.glassdoor.com/Overview/Working-at-Bob-Evans-Restaurants-EI_IE1190.11,32.htm
# --------------------------------------------------
# Company ID: 3322
# https://www.glassdoor.com/Overview/Working-at-Pearson-EI_IE3322.11,18.htm
# https://www.glassdoor.com/Overview/Working-at-Pearson-Education-Services-EI_IE513386.11,37.htm
# --------------------------------------------------
# Company ID: 234929
# https://www.glassdoor.com/Overview/Working-at-CLP-Resources-EI_IE24038.11,24.htm
# https://www.glassdoor.com/Overview/Working-at-Labor-Ready-EI_IE234929.11,22.htm
# --------------------------------------------------
# Company ID: 241146
# https://www.glassdoor.com/Overview/Working-at-Century-Communities-EI_IE241146.11,30.htm
# https://www.glassdoor.com/Overview/Working-at-Benchmark-Communities-EI_IE1190418.11,32.htm
# --------------------------------------------------
# Company ID: 42820
# https://www.glassdoor.com/Overview/Working-at-BioTelemetry-EI_IE1032599.11,23.htm
# https://www.glassdoor.com/Overview/Working-at-CardioNet-EI_IE42820.11,20.htm
# --------------------------------------------------

# %%
#find indices for each company related to each URL (for companies with multiple URL's)
companies[companies['Company Id'].isin(three_urls)].loc[:,'Company Id'].sort_values()
# Out:
# 459          3477
# 46498        3477
# 212087       3477
# 209          3480
# 517          3480
# 49989        3480
# 1387        14916
# 46859       14916
# 2173207     14916
# 593        367190
# 45386      367190
# 1249987    367190
# Name: Company Id, dtype: int64

# %%
#drops legacy URL's for companies with three links
indices_to_drop_three_urls = [46498,212087,517,49989,46859,2173207,45386,1249987]

# %%
#find indices for reviews of companies with 2 URL's 
companies[companies['Company Id'].isin(two_urls)].loc[:,'Company Id'].sort_values()
# Out:
# 5080           658
# 521            658
# 33616         1190
# 3223          1190
# 1330724       1985
# 623           1985
# 644           3322
# 47587         3322
# 15213         3489
# 58893         3489
# 52091         7330
# 6364          7330
# 1288          8347
# 22087         8347
# 47165         8690
# 7559          8690
# 47611         9347
# 1517          9347
# 51557        10350
# 7546         10350
# 10692        10648
# 62224        10648
# 54421        11978
# 3908         11978
# 7070         13598
# 18747        13598
# 55741        14790
# 17194        14790
# 47816        40260
# 416          40260
# 49820        42406
# 169          42406
# 25372        42820
# 54127        42820
# 51012       234929
# 9952        234929
# 46392       241146
# 11741       241146
# 45765       320880
# 2650        320880
# 8405        930001
# 58269       930001
# 47804       975783
# 5100        975783
# 46194      1337673
# 140        1337673
# Name: Company Id, dtype: int64

# %%
#drop legacy URL's of companies with 2 URL's
#    these are indices where the true URL is listed second
indices_to_drop_two_urls_actually_second = [5100, 623, 1517, 6364, 10692, 7070, 2650, 3223]

# %%
companies[companies['Company Id'].isin(two_urls)].loc[:,'Company Id'].sort_values().drop(indices_to_drop_two_urls_actually_second)
# Out:
# 5080           658
# 521            658
# 33616         1190
# 1330724       1985
# 644           3322
# 47587         3322
# 15213         3489
# 58893         3489
# 52091         7330
# 1288          8347
# 22087         8347
# 47165         8690
# 7559          8690
# 47611         9347
# 51557        10350
# 7546         10350
# 62224        10648
# 54421        11978
# 3908         11978
# 18747        13598
# 55741        14790
# 17194        14790
# 47816        40260
# 416          40260
# 49820        42406
# 169          42406
# 25372        42820
# 54127        42820
# 51012       234929
# 9952        234929
# 46392       241146
# 11741       241146
# 45765       320880
# 8405        930001
# 58269       930001
# 47804       975783
# 46194      1337673
# 140        1337673
# Name: Company Id, dtype: int64

# %%
#drop legacy URL's of companies with 2 URL's
#    these are indices where the true URL is listed first 
indices_to_drop_two_urls_actually_first = [5080, 47587, 58893, 22087, 47165,
                                           51557, 54421, 55741, 47816, 49820, 
                                           54127, 51012, 46392, 58269, 46194]

# %%
#indices of rows that have Company URL's that don't contain the exact company name in it

#for example, we should drop "https://www.glassdoor.com/Overview/Working-at-Pearson-Education-Services-EI_IE513386.11,37.htm"
#the current URL is "https://www.glassdoor.com/Overview/Working-at-Pearson-EI_IE3322.11,18.htm"

indices_to_drop = indices_to_drop_three_urls + indices_to_drop_two_urls_actually_second + indices_to_drop_two_urls_actually_first

# %%
#drop rows with legacy URL's
companies = companies.drop(indices_to_drop).reset_index()

# %%
#now all company ID's have a unique URL attached to them 
#    (hopefully with the correct company name in it)
companies.loc[:,'Company Id'].value_counts().value_counts()
# Out:
# 1    5833
# Name: Company Id, dtype: int64

# %%
companies.loc[:,'company_name'] = companies.loc[:,'Company URL'].apply(lambda x: " ".join(x.split('-')[2:-1]))

# %%
companies = companies.drop('index',axis=1)

# %%
companies.columns
# Out:
# Index(['Ticker Symbol', 'Ticker Sector', 'Ticker Industry', 'Company Id',
#        'Company URL', 'company_name'],
#       dtype='object')

# %% [markdown]
# We will later add a column to companies that states how many times that company has been reviewed.

# %% [markdown]
# ## Available jobs at companies
#
# We will now create a DataFrame that states how many times each job title at each company has been reviewed. The columns will be:
# - `Company Id`
# - `company_name`
# - `Job Title`
# - `Employee Status`
# - `count`
#
# A major task will be dealing with erroneously inputted job titles. For example, ~2,200 Starbucks employees wrote their job title as 'Barista - Starbucks' instead of 'Barista'. I choose to simply ignore all of these reviews, since they add up to less than $1\%$ of my 2.5 million reviews.

# %% [markdown]
# The `reviews` DataFrame has one column called `Author Title` which lists positions of reviewers in the format "Employee Type - Job Title".
#
# Let's look at if all of the author titles are of the same format "Employee Type - Job Title" with exactly one dash.

# %%
#see how many dashes are in each author title
#    note that vast majority of job titles (like 'Engineer') have no dashes
reviews.loc[:,'title_length'] = reviews.loc[:,'Author Title'].apply(lambda x: len(x.split(' - ')))

# %%
reviews.loc[:,'title_length'].value_counts()
# Out:
# 2    2615691
# 3      16131
# 4         73
# 1         30
# 5          2
# Name: title_length, dtype: int64

# %%
#look at reviews with only one dash
reviews[reviews['title_length'] == 1].loc[:,'Author Title'].value_counts()
# Out:
# Current Employee -      19
# Former Employee -        9
# Current Contractor -     2
# Name: Author Title, dtype: int64

# %% [markdown]
# We see that these author titles with only one dash simply didn't inclue a job title. Since these form such a small proportion of the reviews (<<1$\%$), we choose to simply drop these reviews.

# %%
reviews = reviews[reviews['title_length'] > 1]

# %% [markdown]
# Let's now look at the unconventional reviews that aren't in the simple format of having one dash: "Employee Status -  Job Position".

# %%
reviews[reviews['title_length'] > 2].loc[:,'Author Title'].value_counts()
# Out:
# Current Employee - Barista - Starbucks                                                   1263
# Former Employee - Barista - Starbucks                                                    1112
# Current Employee - Associate - Projects                                                   762
# Former Intern - Intern - Hourly                                                           710
# Current Intern - Intern - Hourly                                                          486
# Former Employee - Intern - Hourly                                                         463
# Current Employee - Intern - Hourly                                                        312
# Current Employee - Vice President - Technology                                            252
# Former Employee - Associate - Projects                                                    252
# Current Employee - Senior Associate - Projects                                            226
# Former Employee - Guest Service Team Member - Cashier                                     155
# Former Employee - Vice President - Technology                                             132
# Current Employee - CSA - Customer Service Associate                                       103
# Current Employee - Guest Service Team Member - Cashier                                    102
# Current Employee - Manager - Projects                                                      74
# Current Employee - Executive Team Leader - Logistics                                       72
# Former Employee - Sales Associate - Part Time                                              70
# Former Employee - Senior Associate - Projects                                              69
# Former Employee - CSA - Customer Service Associate                                         54
# Former Employee - Executive Team Leader - Logistics                                        53
# Current Employee - Cashier - Front End                                                     52
# Former Intern - Intern - Monthly                                                           49
# Current Employee - Apple Retail - Expert                                                   49
# Current Employee - Sales Advisor - Full Time                                               49
# Current Employee - Technology Lead - USA                                                   49
# Former Employee - Cast Member - Part Time                                                  47
# Former Employee - Cashier - Front End                                                      46
# Current Employee - Executive Team Leader - Human Resources                                 45
# Current Employee - Sales Associate - Stylist                                               41
# Former Employee - Executive Team Leader - Human Resources                                  41
#                                                                                          ...
# Former Employee - Senior Associate Lead - BPHR                                              1
# Former Intern - Technology for Social Good - Archival Internship                            1
# Current Employee - Digital Media Manager - National Brands                                  1
# Former Employee - Sales Associate - Liquor                                                  1
# Current Employee - Commodity Risk Analyst - Energy Trading                                  1
# Current Employee - Senior Team Member ( Corporate Accounts Payable - ASIAPAC )              1
# Former Employee - Process Analyst - Senior Consultant                                       1
# Current Employee - AVP - Software Developer                                                 1
# Former Employee - Tax Adviser - CPA                                                         1
# Former Employee - RDD Engineer V - Mechanical Engineer                                      1
# Former Employee - Branch Management - Assistant Vice President                              1
# Former Employee - Client Service Associate - Operations                                     1
# Current Employee - Senior Management - BD                                                   1
# Current Contractor - Paralegal Specialist - Corporate Services, Treasury                    1
# Current Employee - Bartender - Certified Trainer                                            1
# Current Employee - Senior Associate - Sustainability                                        1
# Current Employee - Case Coordinator - Concierge - Now Customer Service Representative       1
# Current Employee - Customer Service - Bayview                                               1
# Former Employee - Relationship Banker - Small Business Specialist                           1
# Former Employee - Category Manager - GI and Nutritional                                     1
# Current Employee - Director of Banking Advisory - Financial Sponsors                        1
# Current Contractor - Consultant - Project Manager                                           1
# Current Employee - IT Technical Analyst - Virtual                                           1
# Former Employee - Assistant Vice President - Corporate Communications                       1
# Current Employee - SMTS II - Logic Verification Engineering                                 1
# Former Employee - GPM - BEO                                                                 1
# Current Employee - Financial Analyst - Accounts Payable                                     1
# Current Employee - Associate - Trader                                                       1
# Current Employee - Senior Analyst - Customer Insights                                       1
# Former Employee - Vice President - Product & Platform                                       1
# Name: Author Title, dtype: int64

# %% [markdown]
# There are some common issues with the reviews that have at least 2 dashes in "Author Title." For one thing, many of these people mistakenly write when or where they work. Note that these recommendations consists of less than $1\%$ of all the reviews in the dataset. We choose to simply remove them.
#
# The reason is that it's a little tricky to extract and change these- I tried! But also let's think about our goal now. We want to find all of the available jobs at companies. Barista is surely already represented in reviews for Starbucks. Similarly, Associate, Intern, and Vice President should also be represented at those companies for which the bad forms of them are written.

# %%
reviews = reviews[reviews['title_length'] == 2]

# %% [markdown]
# ## Find available jobs at each company
#
# The way we will store jobs is in a new column `available_jobs` in the "Companies" DataFrame. This will be the set of all of the jobs that have had reviews at the row's company.

# %%
companies.head()
# Out:
#    Ticker Symbol      Ticker Sector                  Ticker Industry  \
# 0        vtx:rog        Health Care  Pharmaceuticals & Biotechnology
# 1  bcs:falabella                NaN                              NaN
# 2        asx:wow  Consumer Services            Food & Drug Retailers
# 3        asx:wor                NaN                              NaN
# 4       nyse:xom          Oil & Gas              Oil & Gas Producers
#
#    Company Id                                        Company URL  \
# 0         274  https://www.glassdoor.com/Overview/Working-at-...
# 1       10976  https://www.glassdoor.com/Overview/Working-at-...
# 2      473193  https://www.glassdoor.com/Overview/Working-at-...
# 3       35193  https://www.glassdoor.com/Overview/Working-at-...
# 4         237  https://www.glassdoor.com/Overview/Working-at-...
#
#     company_name
# 0      Genentech
# 1      Falabella
# 2          Big W
# 3  WorleyParsons
# 4     ExxonMobil

# %%
#initialize column 'available_jobs' as empty set
companies.loc[:,'available_jobs'] = pd.Series([set() for idx in range(companies.shape[0])])

# %%
#extracts 'Employee Status' and 'Job Title' from 'Author Title'

reviews.loc[:,'Employee Status'] = reviews.loc[:,'Author Title'].apply(lambda x: x.split(' - ')[0])
reviews.loc[:,'Job Title'] = reviews.loc[:,'Author Title'].apply(lambda x: x.split(' - ')[1])

# %%
#find all unique pairs Company Id-Job Title
company_job = reviews.copy().loc[:, ['Company Id','Job Title']].drop_duplicates().reset_index(drop=True)

# %%
#number of unique pairs is one fifth number of reviews
print(company_job.shape)

company_job.head()
# Out:
# (535356, 2)
#    Company Id             Job Title
# 0         274  Anonymous Contractor
# 1       10976       Senior Engineer
# 2      473193    Anonymous Employee
# 3       35193    Anonymous Employee
# 4         237           I T Analyst

# %%
company_available_jobs = pd.Series(data=[set() for idx in range(companies.shape[0])], index=companies.loc[:,'Company Id'])

# %%
start_time = time.time()

company_job.apply(lambda row: company_available_jobs[row['Company Id']].add(row['Job Title']), axis=1)
    
print('Took ' + str(time.time()-start_time) + ' seconds.')
# Out:
# Took 22.18036985397339 seconds.
# 1000

# %%
company_available_jobs.head(30)
# Out:
# Company Id
# 274        {Project and Process Engineering, Assistant Sc...
# 10976      {Senior Engineer, Digital Content Producer, IT...
# 473193     {Presentation Associate, Fill Associate, Onlin...
# 35193      {Services, CAD Designer, Document Control Spec...
# 237        {Electrician, Store, Construction Superintende...
# 137        {Process Support, Short Term Disability Repres...
# 1033056    {Administrative Assistant, Human Resources, Of...
# 6826       {R/C, Correction Officer, Administrative Assis...
# 15057      {Order Entry Specialist, Staff Engineer, Techn...
# 17798      {Loan Processor Associate, Servicing Systems A...
# 16559      {Securitas Security Guard, Security Officer/Co...
# 2800       {Credit Risk Analyst, Off Cycle, Core Strategi...
# 1737       {QA Automation Engineer, Technician Support An...
# 599        {R&D Chemist, Store, Lead Developer, Office Ma...
# 1202       {Financial Consultant, Wire Specialist, Compli...
# 404        {Service Mechanic, Electrician, Senior Electro...
# 1347599    {Marketing Analyst, Manager Architectural Engi...
# 97         {Solutions Specialist & Cashier, Counter Agent...
# 340        {Learning Technology Consultant, Business Arch...
# 1242       {Clinical& Physician Strategist, Senior Suppor...
# 3522       {Area Business Manager, Administrative Assista...
# 403        {Administrative Assistant, Human Resources, Pr...
# 1079       {Assistant Merchandise Planner, Office Manager...
# 663        {Business Sales, Administrative Assistant, Ana...
# 9011       {Credit Risk Analyst, CSR/Hourly Manager, Well...
# 6036       {Infrastructure Operations, Warehouseman, Offi...
# 1838       {Business Professional, Office Manager, Accoun...
# 92         {Plant Engineer, Electro-mechanical Technician...
# 488        {Logistic Engineer Level V, International Trad...
# 473976     {Executive Manager, Sales Supervisor, Buyer, S...
# dtype: object

# %%
total_jobs_companies = company_available_jobs.apply(lambda x: len(x)).sum()

#number of jobs in lists of company available jobs agrees 
#    with the number of distinct jobs in company_job
assert(total_jobs_companies == company_job.shape[0])

# %%
#find erroneous employee statuses
set(reviews.loc[:,'Employee Status'])
# Out:
# {'Current Apprentice',
#  'Current Contractor',
#  'Current Employee',
#  'Current Freelancer',
#  'Current Intern',
#  'Current PhD',
#  'Current Trainee',
#  'Former Apprentice',
#  'Former Contractor',
#  'Former Employee',
#  'Former Freelancer',
#  'Former Intern',
#  'Former PhD',
#  'Former Trainee',
#  'module.emp-review.current-',
#  'module.emp-review.former-'}

# %%
reviews = reviews[reviews['Employee Status'] != 'module.emp-review.current-'] #remove 4 reviews

# %%
reviews = reviews[reviews['Employee Status'] != 'module.emp-review.former-'] #remove 6 reviews

# %%
reviews.loc[:,'current_or_former'] = reviews.loc[:,'Employee Status'].apply(lambda x: x.split(' ')[0])

# %%
#DataFrame of all triples of company ID, employee status, job title
reviews_company_status_title = reviews.copy().loc[:,['Company Id', 'Employee Status', 'Job Title']]

# %%
reviews_company_status_title.head(10)
# Out:
#    Company Id     Employee Status             Job Title
# 0         274  Current Contractor  Anonymous Contractor
# 1       10976    Current Employee       Senior Engineer
# 2      473193    Current Employee    Anonymous Employee
# 3       35193     Former Employee    Anonymous Employee
# 4         237     Former Employee           I T Analyst
# 5         137    Current Employee     Welder/Fabricator
# 6     1033056    Current Employee               Quality
# 7        6826     Former Employee  Administrative Clerk
# 8       15057    Current Employee    Anonymous Employee
# 9       17798     Former Employee    Anonymous Employee

# %%
reviews_company_status_title_counts = reviews_company_status_title.groupby(by=['Company Id', 'Job Title', 'Employee Status'])['Employee Status'].count()

# %%
reviews_company_status_title_counts = pd.DataFrame({'count': reviews_company_status_title.groupby(['Company Id', 'Job Title', 'Employee Status']).size()}).reset_index()

# %%
#how many times each job title has been reviewed at each company
reviews_company_status_title_counts.head()
# Out:
#    Company Id          Job Title    Employee Status  count
# 0           4                A&P   Current Employee      1
# 1           4           A&P Lead   Current Employee      1
# 2           4  A&P Lead Mechanic   Current Employee      1
# 3           4       A&P Mechanic   Current Employee      1
# 4           4       A&P Mechanic  Former Contractor      2

# %%
reviews_company_status_title_counts = reviews_company_status_title_counts.merge(companies.loc[:,['Company Id','company_name']], on='Company Id')

# %%
reviews_company_count = reviews_company_status_title_counts.loc[:,['Company Id', 'count']]

# %%
#number of reviews for each company
reviews_company_total = reviews_company_status_title_counts.groupby('Company Id')['count'].count().reset_index()

# %%
#company Id 1071540 no longer in set of reviews (due to dropping rows)
set(companies.loc[:,'Company Id']) - set(reviews_company_total.loc[:, 'Company Id'])
# Out:
# {1071540}

# %%
#remove row with company Id 1071540
companies = companies[companies['Company Id'] != 1071540]

# %%
companies = companies.drop('available_jobs', axis=1)

# %%
#add column that states how many times each company has been reviewed
companies = companies.merge(reviews_company_total, on='Company Id')

# %%
companies
# Out:
#       Ticker Symbol      Ticker Sector                   Ticker Industry  \
# 0           vtx:rog        Health Care   Pharmaceuticals & Biotechnology
# 1     bcs:falabella                NaN                               NaN
# 2           asx:wow  Consumer Services             Food & Drug Retailers
# 3           asx:wor                NaN                               NaN
# 4          nyse:xom          Oil & Gas               Oil & Gas Producers
# 5          nyse:cat        Industrials            Industrial Engineering
# 6          nyse:wrk        Industrials               General Industrials
# 7          nyse:cxw         Financials                 General Financial
# 8          lon:mcro         Technology      Software & Computer Services
# 9          nyse:phh        Industrials         Industrial Transportation
# 10       sto:secu-b                NaN                               NaN
# 11          nyse:gs         Financials                Financial Services
# 12        nyse:orcl         Technology      Software & Computer Services
# 13         nyse:shw        Industrials          Construction & Materials
# 14         nyse:snv         Financials                             Banks
# 15         nyse:lmt        Industrials               Aerospace & Defense
# 16         nyse:deg     Consumer Goods                    Food Producers
# 17         nyse:bby  Consumer Services                 General Retailers
# 18         nyse:hum        Health Care  Health Care Equipment & Services
# 19      nasdaq:cern         Technology      Software & Computer Services
# 20         nyse:caj         Technology   Technology Hardware & Equipment
# 21         nyse:lnc         Financials                    Life Insurance
# 22           nyse:m  Consumer Services                 General Retailers
# 23         nyse:tif  Consumer Services                 General Retailers
# 24          nyse:bp          Oil & Gas               Oil & Gas Producers
# 25      nasdaq:amzn  Consumer Services                 General Retailers
# 26         nyse:rhi        Industrials                  Support Services
# 27         nyse:bms        Industrials               General Industrials
# 28         nyse:noc        Industrials               Aerospace & Defense
# 29        nyse:brfs     Consumer Goods                    Food Producers
# ...             ...                ...                               ...
# 5802     otcbb:rdwd                NaN                               NaN
# 5803    nasdaq:dgas          Utilities      Gas, Water & Multi-utilities
# 5804     otcbb:pnbi                NaN                               NaN
# 5805     otcbb:govx                NaN  Health Care Equipment & Services
# 5806     otcbb:seye                NaN                               NaN
# 5807    nasdaq:grbk                NaN                   Household Goods
# 5808     otcbb:tmcv                NaN                               NaN
# 5809    nasdaq:lgnd        Health Care   Pharmaceuticals & Biotechnology
# 5810    nasdaq:cvbf         Financials                             Banks
# 5811        cph:gen        Health Care   Pharmaceuticals & Biotechnology
# 5812        nyse:ai         Financials                Financial Services
# 5813    otcbb:xsonf                NaN                               NaN
# 5814     otcbb:fetm         Financials                             Banks
# 5815        asx:era                NaN                               NaN
# 5816       nyse:alx         Financials                 General Financial
# 5817    nasdaq:orrf                NaN                             Banks
# 5818     otcbb:nxps                NaN                               NaN
# 5819    nasdaq:agnc         Financials                 General Financial
# 5820     otcbb:eacc                NaN                               NaN
# 5821     otcbb:escc                NaN                               NaN
# 5822     otcbb:orxe                NaN                               NaN
# 5823     otcbb:elco                NaN                               NaN
# 5824       nyse:gxp          Utilities                       Electricity
# 5825    nasdaq:scln        Health Care   Pharmaceuticals & Biotechnology
# 5826     otcbb:ldis                NaN                               NaN
# 5827   nasdaq:forty         Technology      Software & Computer Services
# 5828     otcbb:ihti                NaN                               NaN
# 5829     otcbb:fmyr                NaN                               NaN
# 5830     otcbb:amgi                NaN                               NaN
# 5831     otcbb:mpad                NaN                               NaN
#
#       Company Id                                        Company URL  \
# 0            274  https://www.glassdoor.com/Overview/Working-at-...
# 1          10976  https://www.glassdoor.com/Overview/Working-at-...
# 2         473193  https://www.glassdoor.com/Overview/Working-at-...
# 3          35193  https://www.glassdoor.com/Overview/Working-at-...
# 4            237  https://www.glassdoor.com/Overview/Working-at-...
# 5            137  https://www.glassdoor.com/Overview/Working-at-...
# 6        1033056  https://www.glassdoor.com/Overview/Working-at-...
# 7           6826  https://www.glassdoor.com/Overview/Working-at-...
# 8          15057  https://www.glassdoor.com/Overview/Working-at-...
# 9          17798  https://www.glassdoor.com/Overview/Working-at-...
# 10         16559  https://www.glassdoor.com/Overview/Working-at-...
# 11          2800  https://www.glassdoor.com/Overview/Working-at-...
# 12          1737  https://www.glassdoor.com/Overview/Working-at-...
# 7      Corrections Corporation of America     83
# 8                             Micro Focus    204
# 9                            PHH Mortgage    140
# 10        Securitas Security Services USA    367
# 11                          Goldman Sachs    717
# 12                                 Oracle   2783
# 13                       Sherwin Williams    528
# 14                                Synovus     89
# 15                        Lockheed Martin   1696
# 16                         Ahold Delhaize     36
# 17                               Best Buy   2149
# 18                                 Humana    838
# 19                                 Cerner    539
# 20                                  Canon    158
# 21                Lincoln Financial Group    261
# 22                                 Macy s   2290
# 23                         Tiffany and Co    245
# 24                                     BP    955
# 25                                 Amazon   4116
# 26                            Robert Half    772
# 27                                  Bemis    106
# 28                       Northrop Grumman   1279
# 29                           Brasil Foods      8
# ...                                   ...    ...
# 5802                        S3 Investment      1
# 5803                    Delta Natural Gas      1
# 5804                   Pioneer Bankshares      1
# 5805                               GeoVax      1
# 5806                    Signature Eyewear      1
# 5807                              BioFuel      1
# 5808              Temecula Valley Bancorp      1
# 5809               Ligand Pharmaceuticals      1
# 5810                        CVB Financial      1
# 5811                               Genmab      2
# 5812           Arlington Asset Investment      1
# 5813                  Claxson Interactive      1
# 5814                    Fentura Financial      1
# 5815    ERA Energy Resources of Australia      1
# 5816                          Alexander s      1
# 5817                   Orrstown Financial      1
# 5818                             NexPrise      1
# 5819              American Capital Agency      1
# 5820                          eAutoclaims      1
# 5821                 Evans and Sutherland      1
# 5822                  Ore Pharmaceuticals      1
# 5823                                Eleco      1
# 5824                  Great Plains Energy      1
# 5825                             SciClone      1
# 5826                               Leadis      1
# 5827                      Formula Systems      1
# 5828  Integrative Health Technologies Inc      1
# 5829            Family Room Entertainment      1
# 5830                  American Mold Guard      1
# 5831                  Micropac Industries      1
#
# [5832 rows x 7 columns]

# %%
#find percentage of companies that have at most each number of reviews
companies_percentages = (companies.loc[:,'count'].value_counts()*100/5832)

companies_percentages.cumsum()
# Out:
# 1         4.972565
# 2         9.087791
# 3        13.185871
# 4        16.923868
# 5        20.541838
# 6        23.593964
# 7        26.217421
# 8        28.497942
# 9        30.401235
# 10       32.270233
# 11       33.779150
# 13       35.270919
# 12       36.728395
# 14       38.185871
# 15       39.283265
# 17       40.346365
# 19       41.409465
# 16       42.455418
# 18       43.432785
# 28       44.290123
# 32       45.113169
# 20       45.919067
# 22       46.724966
# 24       47.496571
# 23       48.216735
# 25       48.936900
# 26       49.622771
# 31       50.308642
# 21       50.925926
# 29       51.543210
#            ...
# 610      99.502743
# 614      99.519890
# 326      99.537037
# 318      99.554184
# 314      99.571331
# 290      99.588477
# 1185     99.605624
# 1201     99.622771
# 1253     99.639918
# 1257     99.657064
# 1373     99.674211
# 1425     99.691358
# 1477     99.708505
# 1589     99.725652
# 1919     99.742798
# 1693     99.759945
# 1729     99.777092
# 1913     99.794239
# 2025     99.811385
# 2045     99.828532
# 4116     99.845679
# 2071     99.862826
# 2091     99.879973
# 2131     99.897119
# 198      99.914266
# 4300     99.931413
# 214      99.948560
# 234      99.965706
# 278      99.982853
# 3644    100.000000
# Name: count, dtype: float64

# %%
reviews_company_status_title_counts = reviews_company_status_title_counts.loc[:,['Company Id', 'company_name', 'Job Title', 'Employee Status', 'count']]

# %%
reviews_company_status_title_counts
# Out:
#         Company Id               company_name  \
# 0                4                        AAR
# 1                4                        AAR
# 2                4                        AAR
# 3                4                        AAR
# 4                4                        AAR
# 5                4                        AAR
# 6                4                        AAR
# 7                4                        AAR
# 8                4                        AAR
# 9                4                        AAR
# 10               4                        AAR
# 11               4                        AAR
# 12               4                        AAR
# 13               4                        AAR
# 14               4                        AAR
# 15               4                        AAR
# 16               4                        AAR
# 17               4                        AAR
# 18               4                        AAR
# 19               4                        AAR
# 20               4                        AAR
# 21               4                        AAR
# 22               4                        AAR
# 23               4                        AAR
# 24               4                        AAR
# 25               4                        AAR
# 26               4                        AAR
# 27               4                        AAR
# 28               4                        AAR
# 29               4                        AAR
# ...            ...                        ...
# 653933     2112843                  Perspecta
# 653934     2112843                  Perspecta
# 653935     2112843                  Perspecta
# 653936     2112843                  Perspecta
# 653937     2112843                  Perspecta
# 653938     2112843                  Perspecta
# 653939     2112843                  Perspecta
# 653940     2112843                  Perspecta
# 653941     2112843                  Perspecta
# 653942     2112843                  Perspecta
# 653943     2112843                  Perspecta
# 653944     2112843                  Perspecta
# 653945     2134135           Keurig Dr Pepper
# 653946     2134135           Keurig Dr Pepper
# 653947     2134135           Keurig Dr Pepper
# 653948     2134135           Keurig Dr Pepper
# 653949     2134135           Keurig Dr Pepper
# 653950     2134135           Keurig Dr Pepper
# 653951     2134135           Keurig Dr Pepper
# 653952     2134135           Keurig Dr Pepper
# 653953     2134135           Keurig Dr Pepper
# 653954     2134135           Keurig Dr Pepper
# 653955     2134135           Keurig Dr Pepper
# 653956     2134135           Keurig Dr Pepper
# 653957     2134135           Keurig Dr Pepper
# 653958     2134135           Keurig Dr Pepper
# 653959     2134135           Keurig Dr Pepper
# 653960     2134135           Keurig Dr Pepper
# 653961     2134135           Keurig Dr Pepper
# 653962     2146572  Unibail Rodamco Westfield
#
#                               Job Title     Employee Status  count
# 0                                   A&P    Current Employee      1
# 1                              A&P Lead    Current Employee      1
# 2                     A&P Lead Mechanic    Current Employee      1
# 3                          A&P Mechanic    Current Employee      1
# 4                          A&P Mechanic   Former Contractor      2
# 5                          A&P Mechanic     Former Employee      5
# 6                        A&P Technician    Current Employee      3
# 7                           AP Mechanic     Former Employee      1
# 8                            Accountant    Current Employee      1
# 9                        Administrative    Current Employee      1
# 10             Administrative Assistant    Current Employee      1
# 11                   Aircraft Inspector    Current Employee      1
# 12      Aircraft Maintenance Technician    Current Employee      1
# 13      Aircraft Maintenance Technician     Former Employee      1
# 14                    Aircraft Mechanic  Current Contractor      1
# 15                    Aircraft Mechanic    Current Employee      3
# 16                    Aircraft Mechanic     Former Employee      3
# 17                  Aircraft Technician     Former Employee      1
# 18                                  Amt    Current Employee      1
# 19                              Analyst    Current Employee      2
# 20                              Analyst     Former Employee      1
# 21                            Anonymous     Former Employee      1
# 22                 Anonymous Contractor   Former Contractor      6
# 23                   Anonymous Employee    Current Employee     66
# 24                   Anonymous Employee     Former Employee     49
# 25                     Anonymous Intern       Former Intern      1
# 26                       Assembaly Tech     Former Employee      1
# 27                        Assembly Tech     Former Employee      1
# 28                  Assembly Technician     Former Employee      1
# 29      Aviation Maintenance Technician    Current Employee      1
# ...                                 ...                 ...    ...
# 653933        Physical Security Officer    Current Employee      1
# 653934                  Program Manager    Current Employee      1
# 653935                  Project Manager    Current Employee      2
# 653936          Regional Field Director    Current Employee      1
# 653937        Reviewer and Investigator    Current Employee      1
# 653938          Security and Compliance  Current Contractor      1
# 653939          Senior Systems Engineer    Current Employee      1
# 653940             Special Investigator    Current Employee      1
# 653941                 Systems Engineer    Current Employee      2
# 653942   Systems Engineering Supervisor    Current Employee      1
# 653943            TIER I HELP DESK TECH   Former Contractor      1
# 653944    Workplace Offering Consultant    Current Employee      1
# 653945                           Anonym    Current Employee      1
# 653946               Anonymous Employee    Current Employee     21
# 653947               Anonymous Employee     Former Employee      4
# 653948                Associate Manager    Current Employee      1
# 653949                         Director    Current Employee      1
# 653950                          Finance     Former Employee      1
# 653951             Maintenance Mechanic    Current Employee      1
# 653952                        Marketing    Current Employee      1
# 653953              Marketing Associate     Former Employee      1
# 653954                     Merchandiser    Current Employee      2
# 653955    Oracle Database Administrator     Former Employee      1
# 653956            Production Technician    Current Employee      1
# 653957                  Project Manager    Current Employee      1
# 653958       Regional Account Executive    Current Employee      1
# 653959        Talent Acquisition Intern       Former Intern      1
# 653960               Tech II Mchine Opp    Current Employee      1
# 653961       Technical Services Analyst    Current Employee      1
# 653962               Anonymous Employee    Current Employee      1
#
# [653963 rows x 5 columns]

# %%
reviews_company_status_title_counts.to_csv('companies_jobs_counts.csv')

# %%
#cumulative percentages of how many times company-job title-count triples have been reviewed
total_reviews = reviews_company_status_title_counts.loc[:,'count'].value_counts().sum()

reviews_company_status_title_counts.loc[:,'count'].value_counts().cumsum()/total_reviews*100
# Out:
# 1        75.599843
# 2        85.898896
# 3        89.805845
# 4        91.993890
# 5        93.341366
# 6        94.312981
# 7        95.007516
# 8        95.552807
# 9        95.982800
# 10       96.334655
# 11       96.618922
# 12       96.860679
# 13       97.072923
# 14       97.259019
# 15       97.417285
# 16       97.552767
# 17       97.670205
# 18       97.782749
# 19       97.880308
# 20       97.972362
# 21       98.056465
# 22       98.133075
# 23       98.201121
# 24       98.262440
# 25       98.321159
# 26       98.378960
# 27       98.430339
# 28       98.480342
# 29       98.523923
# 31       98.567197
#            ...
# 2197     99.995565
# 2872     99.995718
# 824      99.995871
# 309      99.996024
# 663      99.996177
# 3222     99.996330
# 4233     99.996483
# 650      99.996636
# 1865     99.996789
# 843      99.996942
# 635      99.997095
# 2173     99.997248
# 636      99.997400
# 1148     99.997553
# 859      99.997706
# 2394     99.997859
# 638      99.998012
# 2174     99.998165
# 3419     99.998318
# 2904     99.998471
# 1152     99.998624
# 641      99.998777
# 1366     99.998930
# 1365     99.999083
# 1668     99.999235
# 645      99.999388
# 846      99.999541
# 646      99.999694
# 1869     99.999847
# 3582    100.000000
# Name: count, dtype: float64

# %%
companies.to_csv('reviewed_companies.csv')
