# %% [markdown]
# # Fixing companies jobs counts
#
# In the last notebook, we found that our file `companies_available_jobs.csv` was incorrectly produced. It has that every company has been reviewed in the same 67 jobs.
#
# We will fix that here.
#
# For this, we will need to go back to our file `companies_jobs_counts.csv`, which lists how many times each company has been reviewed. We will also need to use our file `all_jobs_ratings.csv`, which contains the 13,000 jobs we have info about.

# %%
import pandas as pd
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows', 90)

import numpy as np

# %% [markdown]
# ## Import job counts and job titles

# %%
#has how many times each job has been reviewed at each company
job_counts = pd.read_csv('companies_jobs_counts.csv', index_col='Unnamed: 0')

#import ratings for jobs I consider
job_ratings = pd.read_csv('all_jobs_ratings_transpose.csv', index_col='Unnamed: 0')

#all jobs at companies I will recommend
all_jobs = job_ratings.loc[:,'Job Title']

# %%
reviewed_companies = pd.read_csv('reviewed_companies.csv', index_col='Unnamed: 0')

# %%
print(reviewed_companies.shape)

reviewed_companies.head()
# Out:
# (5832, 7)
#    Ticker Symbol      Ticker Sector                  Ticker Industry  \
# 0        vtx:rog        Health Care  Pharmaceuticals & Biotechnology
# 1  bcs:falabella                NaN                              NaN
# 2        asx:wow  Consumer Services            Food & Drug Retailers
# 3        asx:wor                NaN                              NaN
# 4       nyse:xom          Oil & Gas              Oil & Gas Producers
#
#    Company Id                                        Company URL  \
# 0         274  https://www.glassdoor.com/Overview/Working-at-...
# 1       10976  https://www.glassdoor.com/Overview/Working-at-...
# 2      473193  https://www.glassdoor.com/Overview/Working-at-...
# 3       35193  https://www.glassdoor.com/Overview/Working-at-...
# 4         237  https://www.glassdoor.com/Overview/Working-at-...
#
#     company_name  count
# 0      Genentech    609
# 1      Falabella      9
# 2          Big W     70
# 3  WorleyParsons    379
# 4     ExxonMobil    845

# %%
job_counts.head()
# Out:
#    Company Id company_name          Job Title    Employee Status  count
# 0           4          AAR                A&P   Current Employee      1
# 1           4          AAR           A&P Lead   Current Employee      1
# 2           4          AAR  A&P Lead Mechanic   Current Employee      1
# 3           4          AAR       A&P Mechanic   Current Employee      1
# 4           4          AAR       A&P Mechanic  Former Contractor      2

# %%
print('Total number of reviews in job_counts: {}'.format(job_counts.loc[:,'count'].sum()))
# Out:
# Total number of reviews in job_counts: 2615681

# %% [markdown]
# ## Restricting job counts
#
# We will only consider jobs that have been reviewed at least 3 times at some company. This will decrease the number of jobs in half.

# %%
#filter job_counts to only jobs that have been reviewed at least 3x
job_counts = job_counts[job_counts.loc[:,'Job Title'].isin(all_jobs)]

# %%
print('Current number of reviews: {}'.format(job_counts.loc[:,'count'].sum()))
# Out:
# Current number of reviews: 1224851

# %%
job_counts.shape
# Out:
# (372136, 5)

# %%
job_counts.loc[:,'Job Title'].drop_duplicates()
# Out:
# 3                                              A&P Mechanic
# 6                                            A&P Technician
# 8                                                Accountant
# 9                                            Administrative
# 10                                 Administrative Assistant
# 12                          Aircraft Maintenance Technician
# 14                                        Aircraft Mechanic
# 18                                                      Amt
# 19                                                  Analyst
# 21                                                Anonymous
# 27                                            Assembly Tech
# 28                                      Assembly Technician
# 29                          Aviation Maintenance Technician
# 32                                      Avionics Technician
# 37                                         Business Analyst
# 38                           Business Development Executive
# 40                                                    Buyer
# 41                                            CNC Machinist
# 42                                                    Clerk
# 43                                     Composite Technician
# 45                                               Contractor
# 46                                      Corporate Recruiter
# 47                                          Desktop Support
# 49                                                   Driver
# 53                                                 Engineer
# 56                                                  Finance
# 58                                       General Production
# 59                                         Helicopter Pilot
# 60                                          Human Resources
# 61                           Human Resources Representative
# 62                                            IT Consultant
# 65                                                   Intern
# 67                                        Inventory Analyst
# 69                                                     Lead
# 74                                                Logistics
# 75                                    Logistics Coordinator
# 78                                               Management
# 79                                                  Manager
# 81                                                 Mechanic
# 84                                                      NaN
# 86                                               Operations
# 90                                                    Pilot
# 92                                          Pricing Analyst
# 93                                    Production Controller
# 94                                    Production Technician
#                                 ...
# 604631                                    Territory Partner
# 605312                                     Myer Team Member
# 606071                             Radio Promotion Director
# 606592                         Customer Operations Engineer
# 606903                             Transaction Specialist I
# 606905                            Transaction Specialist II
# 607054                                      CRM Coordinator
# 608541                                 Retail Solar Advisor
# 609255                          Freelance Writer and Editor
# 611347    Financial Representative (Branch Manager Trainee)
# 611505                           Management Trainee Officer
# 611645                      Night Audit/Laundry, Front Desk
# 611714                               Core Account Executive
# 611721                             Dropbox Rotation Program
# 612092                               Online Sales Executive
# 612103                           Restaurant Care Specialist
# 613628                              Fashion Associate (P/T)
# 614801          Sales Representative/Membership Coordinator
# 615190                            Entrepreneur In Residence
# 615200                                                  GVD
# 615574                   Appraiser (Commercial Real Estate)
# 615611                     Associate Real Estate Accountant
# 615916                             Mobile Building Engineer
# 615994                               Real Estate Accountant
# 616123                        Senior Real Estate Accountant
# 616294                          Hollister Assistant Manager
# 616298                                Hollister Floor Model
# 616346                                          Model & PTI
# 616409                                Sales Associate/Model
# 617210               Receptionist, Administrative Assistant
# 617422                                       Park Attendant
# 617556                           Sunglasshut Sale Associate
# 617804                                 Assembly Team Member
# 619056                         Digital Relationship Advisor
# 619419                                            DTP Sales
# 619422                              Direct to Patient Sales
# 619876                                   Server/Salesperson
# 621578                                Sales Associate- Rack
# 621622                Shoes and Accessories Sales Associate
# 622976                                       Bank Executive
# 623278                   Carrier Procurement Representative
# 623382                                         FABP Analyst
# 623968                        Account Development Associate
# 624381                                        Clinical Team
# 625133                  Senior Sales Service Representative
# Name: Job Title, Length: 13172, dtype: object

# %%
print(job_counts.shape)
job_counts.dropna(axis=0, subset=['Job Title']).head(90)
# Out:
# (372136, 5)
#      Company Id company_name                              Job Title  \
# 3             4          AAR                           A&P Mechanic
# 4             4          AAR                           A&P Mechanic
# 5             4          AAR                           A&P Mechanic
# 6             4          AAR                         A&P Technician
# 8             4          AAR                             Accountant
# 9             4          AAR                         Administrative
# 10            4          AAR               Administrative Assistant
# 12            4          AAR        Aircraft Maintenance Technician
# 13            4          AAR        Aircraft Maintenance Technician
# 14            4          AAR                      Aircraft Mechanic
# 15            4          AAR                      Aircraft Mechanic
# 16            4          AAR                      Aircraft Mechanic
# 18            4          AAR                                    Amt
# 19            4          AAR                                Analyst
# 20            4          AAR                                Analyst
# 21            4          AAR                              Anonymous
# 27            4          AAR                          Assembly Tech
# 28            4          AAR                    Assembly Technician
# 29            4          AAR        Aviation Maintenance Technician
# 32            4          AAR                    Avionics Technician
# 33            4          AAR                    Avionics Technician
# 34            4          AAR                    Avionics Technician
# 37            4          AAR                       Business Analyst
# 38            4          AAR         Business Development Executive
# 40            4          AAR                                  Buyer
# 41            4          AAR                          CNC Machinist
# 42            4          AAR                                  Clerk
# 43            4          AAR                   Composite Technician
# 45            4          AAR                             Contractor
# 46            4          AAR                    Corporate Recruiter
# 47            4          AAR                        Desktop Support
# 49            4          AAR                                 Driver
# 53            4          AAR                               Engineer
# 94      Former Employee      1
# 95     Current Employee      2
# 96      Former Employee      1
# 97      Former Employee      1
# 98     Current Employee      1
# 99      Former Employee      1
# 100     Former Employee      1
# 102    Current Employee      1
# 103    Current Employee      1
# 104   Former Contractor      1
# 107     Former Employee      1
# 108    Current Employee      1
# 112    Current Employee      1
# 113     Former Employee      1
# 114     Former Employee      1
# 116   Former Contractor      1
# 118    Current Employee      1
# 119     Former Employee      1
# 121    Current Employee      1
# 122  Current Contractor      1
# 123    Current Employee      1
# 124   Former Contractor      1
# 125     Former Employee      3
# 128    Current Employee      1
# 131    Current Employee      1
# 132    Current Employee      1
# 133     Former Employee      1
# 135    Current Employee      1
# 136     Former Employee      1
# 137     Former Employee      1
# 138     Former Employee      1
# 139    Current Employee      1
# 149     Former Employee      1
# 153     Former Employee      1
# 154    Current Employee      1
# 156    Current Employee      1

# %%
job_counts.shape
# Out:
# (372136, 5)

# %% [markdown]
# ## Extract jobs reviewed at each company
#
# From the `job_counts` DataFrame, I will find the collection of jobs reviewed at each company. I will then convert this collection into a long string, with job titles separated by the fixed string ' AKLDJJ '. When I import this information in future work, I can just quickly split by ' AKLDJJ '.

# %%
company_jobs_dict = {}

counter = 0

for comp_id in job_counts.loc[:,'Company Id'].drop_duplicates():
    job_counts_for_company = job_counts[job_counts['Company Id'] == comp_id]
    
    #find lists of jobs at company
    company_jobs_dict[comp_id] = list(job_counts_for_company.loc[:,'Job Title'].drop_duplicates())
    
    #remove job titles that were listed as NaN
    if np.nan in company_jobs_dict[comp_id]:
        counter += 1
        company_jobs_dict[comp_id].remove(np.nan)
        
    company_jobs_dict[comp_id] = " AKLDJJ ".join(company_jobs_dict[comp_id])
    
print(counter)
# Out:
# 462

# %%
#example string of jobs at company
company_jobs_dict[20]
# Out:
# 'Composite Technician AKLDJJ Engineer AKLDJJ Finishing Technician AKLDJJ IT Manager AKLDJJ IT Support Analyst AKLDJJ Intern AKLDJJ Manufacturing AKLDJJ Manufacturing Supervisor AKLDJJ Ndt Technician AKLDJJ Process Engineer AKLDJJ Senior Buyer AKLDJJ Senior Manager'

# %%
company_jobs_df = pd.DataFrame.from_dict({'Company Id': [comp_id 
                                                         for comp_id in job_counts.loc[:,'Company Id'].drop_duplicates()],
                                          'Available Jobs': [company_jobs_dict[comp_id]
                                                            for comp_id in job_counts.loc[:,'Company Id'].drop_duplicates()]})

# %%
company_jobs_df.head()
# Out:
#    Company Id                                     Available Jobs
# 0           4  A&P Mechanic AKLDJJ A&P Technician AKLDJJ Acco...
# 1           7  Accounts Payable AKLDJJ Administrative Assista...
# 2           8  A&P Mechanic AKLDJJ Account Manager AKLDJJ Acc...
# 3           9                                   Machine Operator
# 4          12  AREA SALES MANAGER AKLDJJ Abteilungsleiter AKL...

# %%
#a few companies without jobs
company_jobs_df = company_jobs_df[~company_jobs_df['Company Id'].isin([1892,23043,660837])]

# %%
company_jobs_df = company_jobs_df.set_index('Company Id', drop = True)

# %%
company_jobs_df.head()
# Out:
#                                                Available Jobs
# Company Id
# 4           A&P Mechanic AKLDJJ A&P Technician AKLDJJ Acco...
# 7           Accounts Payable AKLDJJ Administrative Assista...
# 8           A&P Mechanic AKLDJJ Account Manager AKLDJJ Acc...
# 9                                            Machine Operator
# 12          AREA SALES MANAGER AKLDJJ Abteilungsleiter AKL...

# %%
#save to CSV file
company_jobs_df.to_csv('companies_available_jobs.csv')
